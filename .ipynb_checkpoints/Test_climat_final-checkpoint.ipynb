# %%
# !pip install esgf-pyclient --progress-bar off

# !pip install pytest --progress-bar off
 
# !pip install flake8 --progress-bar off
 
# !pip install sphinx --progress-bar off
 
# !pip install nbsphinx --progress-bar off
 
# !pip install pandoc --progress-bar off
 
# !pip install ipykernel --progress-bar off
 
# !pip install nbconvert --progress-bar off
 
# !pip install defusedxml --progress-bar off
 
# !pip install jinja2 --progress-bar off
 
# !pip install requests --progress-bar off
 
# !pip install webob --progress-bar off
 
# !pip install myproxyclient --progress-bar off
 
# !pip install nbval --progress-bar off

# !pip install requests_cache==0.5 --progress-bar off

# !pip install xarray --progress-bar off
# Out:
# Requirement already satisfied: esgf-pyclient in c:\users\admin\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: requests-cache in c:\users\admin\anaconda3\lib\site-packages (from esgf-pyclient) (0.5.0)
# Requirement already satisfied: webob in c:\users\admin\anaconda3\lib\site-packages (from esgf-pyclient) (1.8.7)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from esgf-pyclient) (2.11.3)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (from esgf-pyclient) (0.7.1)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from esgf-pyclient) (2.25.1)
# Requirement already satisfied: myproxyclient in c:\users\admin\anaconda3\lib\site-packages (from esgf-pyclient) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->esgf-pyclient) (1.1.1)
# Requirement already satisfied: pyOpenSSL in c:\users\admin\anaconda3\lib\site-packages (from myproxyclient->esgf-pyclient) (20.0.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from myproxyclient->esgf-pyclient) (1.15.0)
# Requirement already satisfied: cryptography>=3.2 in c:\users\admin\anaconda3\lib\site-packages (from pyOpenSSL->myproxyclient->esgf-pyclient) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from cryptography>=3.2->pyOpenSSL->myproxyclient->esgf-pyclient) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->pyOpenSSL->myproxyclient->esgf-pyclient) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->esgf-pyclient) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->esgf-pyclient) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests->esgf-pyclient) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->esgf-pyclient) (2.10)
# Requirement already satisfied: pytest in c:\users\admin\anaconda3\lib\site-packages (6.2.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pytest) (21.2.0)
# Requirement already satisfied: iniconfig in c:\users\admin\anaconda3\lib\site-packages (from pytest) (1.1.1)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from pytest) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in c:\users\admin\anaconda3\lib\site-packages (from pytest) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pytest) (1.10.0)
# Requirement already satisfied: toml in c:\users\admin\anaconda3\lib\site-packages (from pytest) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from pytest) (1.4.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from pytest) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->pytest) (2.4.7)
# Requirement already satisfied: flake8 in c:\users\admin\anaconda3\lib\site-packages (3.9.0)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in c:\users\admin\anaconda3\lib\site-packages (from flake8) (2.7.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from flake8) (0.6.1)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in c:\users\admin\anaconda3\lib\site-packages (from flake8) (2.3.1)
# Requirement already satisfied: sphinx in c:\users\admin\anaconda3\lib\site-packages (4.0.1)
# Requirement already satisfied: colorama>=0.3.5 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (0.4.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.1.4)
# Requirement already satisfied: imagesize in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.2.0)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (52.0.0.post20210125)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (20.9)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.0.2)
# Requirement already satisfied: docutils<0.18,>=0.14 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (0.17)
# Requirement already satisfied: babel>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (2.9.0)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (2.1.0)
# Requirement already satisfied: MarkupSafe<2.0 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.1.1)
# Requirement already satisfied: Pygments>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (2.8.1)
# Requirement already satisfied: requests>=2.5.0 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (2.25.1)
# Requirement already satisfied: Jinja2<3.0,>=2.3 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (2.11.3)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (0.7.12)
# Requirement already satisfied: sphinxcontrib-htmlhelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx) (1.0.3)
# Requirement already satisfied: pytz>=2015.7 in c:\users\admin\anaconda3\lib\site-packages (from babel>=1.3->sphinx) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->sphinx) (2.4.7)
# Requirement already satisfied: nbsphinx in c:\users\admin\anaconda3\lib\site-packages (0.8.7)
# Requirement already satisfied: sphinx>=1.8 in c:\users\admin\anaconda3\lib\site-packages (from nbsphinx) (4.0.1)
# Requirement already satisfied: traitlets in c:\users\admin\anaconda3\lib\site-packages (from nbsphinx) (5.0.5)
# Requirement already satisfied: docutils in c:\users\admin\anaconda3\lib\site-packages (from nbsphinx) (0.17)
# Requirement already satisfied: nbconvert!=5.4 in c:\users\admin\anaconda3\lib\site-packages (from nbsphinx) (6.0.7)
# Requirement already satisfied: nbformat in c:\users\admin\anaconda3\lib\site-packages (from nbsphinx) (5.1.3)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from nbsphinx) (2.11.3)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (2.8.1)
# Requirement already satisfied: testpath in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (4.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (1.4.3)
# Requirement already satisfied: bleach in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (3.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (0.3)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert!=5.4->nbsphinx) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->nbsphinx) (1.1.1)
# Requirement already satisfied: async-generator in c:\users\admin\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\admin\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\admin\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx) (2.8.1)
# Requirement already satisfied: tornado>=4.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx) (6.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-core->nbconvert!=5.4->nbsphinx) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from nbformat->nbsphinx) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\admin\anaconda3\lib\site-packages (from nbformat->nbsphinx) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx) (0.17.3)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx) (52.0.0.post20210125)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx) (1.15.0)
# Requirement already satisfied: babel>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (2.9.0)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.0.2)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (2.1.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.1.4)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (0.7.12)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (20.9)
# Requirement already satisfied: requests>=2.5.0 in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (2.25.1)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.0.1)
# Requirement already satisfied: colorama>=0.3.5 in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (0.4.4)
# Requirement already satisfied: sphinxcontrib-htmlhelp in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.0.3)
# Requirement already satisfied: imagesize in c:\users\admin\anaconda3\lib\site-packages (from sphinx>=1.8->nbsphinx) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\admin\anaconda3\lib\site-packages (from babel>=1.3->sphinx>=1.8->nbsphinx) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx) (2.10)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\lib\site-packages (from bleach->nbconvert!=5.4->nbsphinx) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->sphinx>=1.8->nbsphinx) (2.4.7)
# Requirement already satisfied: pandoc in c:\users\admin\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: ply in c:\users\admin\anaconda3\lib\site-packages (from pandoc) (3.11)
# Requirement already satisfied: plumbum in c:\users\admin\anaconda3\lib\site-packages (from pandoc) (1.7.1)
# Requirement already satisfied: pypiwin32 in c:\users\admin\anaconda3\lib\site-packages (from plumbum->pandoc) (223)
# Requirement already satisfied: pywin32>=223 in c:\users\admin\anaconda3\lib\site-packages (from pypiwin32->plumbum->pandoc) (227)
# Requirement already satisfied: ipykernel in c:\users\admin\anaconda3\lib\site-packages (5.3.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\admin\anaconda3\lib\site-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel) (7.22.0)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel) (5.0.5)
# Requirement already satisfied: backcall in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.17.2)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (3.0.17)
# Requirement already satisfied: pygments in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (52.0.0.post20210125)
# Requirement already satisfied: pickleshare in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.7.5)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\admin\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->ipykernel) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->ipykernel) (2.8.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->ipykernel) (4.7.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel) (227)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel) (1.15.0)
# Requirement already satisfied: nbconvert in c:\users\admin\anaconda3\lib\site-packages (6.0.7)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (1.4.3)
# Requirement already satisfied: testpath in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (0.3)
# Requirement already satisfied: bleach in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (3.3.0)
# Requirement already satisfied: nbformat>=4.4 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (5.1.3)
# Requirement already satisfied: jinja2>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (2.11.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (2.8.1)
# Requirement already satisfied: jupyter-core in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (4.7.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert) (5.0.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert) (1.1.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\admin\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (6.1.12)
# Requirement already satisfied: async-generator in c:\users\admin\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\admin\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.5.1)
# Requirement already satisfied: tornado>=4.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-core->nbconvert) (227)
# Requirement already satisfied: ipython-genutils in c:\users\admin\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert) (3.2.0)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (52.0.0.post20210125)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\lib\site-packages (from bleach->nbconvert) (0.5.1)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from bleach->nbconvert) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->bleach->nbconvert) (2.4.7)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from jinja2) (1.1.1)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: webob in c:\users\admin\anaconda3\lib\site-packages (1.8.7)
# Requirement already satisfied: myproxyclient in c:\users\admin\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from myproxyclient) (1.15.0)
# Requirement already satisfied: pyOpenSSL in c:\users\admin\anaconda3\lib\site-packages (from myproxyclient) (20.0.1)
# Requirement already satisfied: cryptography>=3.2 in c:\users\admin\anaconda3\lib\site-packages (from pyOpenSSL->myproxyclient) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from cryptography>=3.2->pyOpenSSL->myproxyclient) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->pyOpenSSL->myproxyclient) (2.20)
# Requirement already satisfied: nbval in c:\users\admin\anaconda3\lib\site-packages (0.9.6)
# Requirement already satisfied: jupyter-client in c:\users\admin\anaconda3\lib\site-packages (from nbval) (6.1.12)
# Requirement already satisfied: ipykernel in c:\users\admin\anaconda3\lib\site-packages (from nbval) (5.3.4)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from nbval) (1.15.0)
# Requirement already satisfied: pytest>=2.8 in c:\users\admin\anaconda3\lib\site-packages (from nbval) (6.2.3)
# Requirement already satisfied: coverage in c:\users\admin\anaconda3\lib\site-packages (from nbval) (6.2)
# Requirement already satisfied: nbformat in c:\users\admin\anaconda3\lib\site-packages (from nbval) (5.1.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (21.2.0)
# Requirement already satisfied: iniconfig in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (1.1.1)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (1.10.0)
# Requirement already satisfied: toml in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (1.4.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from pytest>=2.8->nbval) (0.4.4)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel->nbval) (7.22.0)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel->nbval) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel->nbval) (6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (52.0.0.post20210125)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (5.0.6)
# Requirement already satisfied: backcall in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (0.7.5)
# Requirement already satisfied: pygments in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->nbval) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->nbval) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->nbval) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\admin\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->nbval) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->nbval) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->nbval) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->nbval) (4.7.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->nbval) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from nbformat->nbval) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbval) (0.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->pytest>=2.8->nbval) (2.4.7)
# Requirement already satisfied: requests_cache==0.5 in c:\users\admin\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: requests>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from requests_cache==0.5) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=1.1.0->requests_cache==0.5) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=1.1.0->requests_cache==0.5) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=1.1.0->requests_cache==0.5) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=1.1.0->requests_cache==0.5) (2020.12.5)
# Requirement already satisfied: xarray in c:\users\admin\anaconda3\lib\site-packages (0.20.1)
# Requirement already satisfied: numpy>=1.18 in c:\users\admin\anaconda3\lib\site-packages (from xarray) (1.20.1)
# Requirement already satisfied: pandas>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from xarray) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.1->xarray) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.1->xarray) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1->xarray) (1.15.0)

# %%
from pyesgf.search import SearchConnection
import os
import pandas as pd
import requests
from tqdm import tqdm

import datetime as dt
import numpy as np
import pandas as pd
import re
from matplotlib import pyplot as plt
from netCDF4 import Dataset, date2index, num2date, date2num
import xarray as xr

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
from netCDF4 import Dataset, date2index, num2date, date2num

# %%
cities  = os.listdir('Coordonnees_contours_sous-bassins/')

# %%
bangui = pd.read_excel('Coordonnees_contours_sous-bassins/Bangui_pts.xlsx', index_col=0, dtype={'id': int, 'lat': float, 'long': float})
banguiValues = []
for row in bangui.iterrows():
  banguiValues.append([row[1].long, row[1].lat])
  
polygonBangui = Polygon(banguiValues)

# %%
models=['inmcm4',
         'bcc-csm1-1',
         'NorESM1-M',
         'MRI-CGCM3',
         'MPI-ESM-MR',
         'MPI-ESM-LR',
         'MIROC5',	
         'MIROC-ESM',
         'MIROC-ESM-CHEM',
         'IPSL-CM5A-MR',
         'IPSL-CM5A-LR',
         'GFDL-ESM2M',
         'GFDL-ESM2G',
         'GFDL-CM3',
         'CanESM2',
         'CSIRO-Mk3-6-0',
         'CNRM-CM5',
         'CESM1-BGC',
         'CCSM4',
         'BNU-ESM',
         'ACCESS1-0']
experimets = ['rcp45', 'rcp85', 'historical']

# %%
for experiment in experimets:
  print(experiment)

  for model in models:

    opendap_tasmin = 'https://ds.nccs.nasa.gov/thredds/dodsC/bypass/NEX-GDDP/bcsd/' + experiment + '/r1i1p1/tasmin/'+ model +'.ncml'
    opendap_tasmax = 'https://ds.nccs.nasa.gov/thredds/dodsC/bypass/NEX-GDDP/bcsd/' + experiment + '/r1i1p1/tasmax/'+ model +'.ncml'
    opendap_pr = 'https://ds.nccs.nasa.gov/thredds/dodsC/bypass/NEX-GDDP/bcsd/' + experiment + '/r1i1p1/pr/'+ model +'.ncml'

    data_tasmin = xr.open_dataset(opendap_tasmin)
    data_tasmax = xr.open_dataset(opendap_tasmax)
    data_pr = xr.open_dataset(opendap_pr)

    data_all = xr.merge([data_tasmin, data_tasmax, data_pr])
    print(model)
    print(data_all.variables)
# Out:
# rcp45
# inmcm4
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:29:39Z
#     forcing:                        N/A
#     product:                        output
# bcc-csm1-1
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34310)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2099-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:11:25Z
#     forcing:                        N/A
#     product:                        output
# NorESM1-M
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:46:17Z
#     forcing:                        N/A
#     product:                        output
# MRI-CGCM3
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34698)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2006-01-01T12:00:00 ... 2100-12-31T12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:44:31Z
#     forcing:                        N/A
#     product:                        output
# MPI-ESM-MR
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34698)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2006-01-01T12:00:00 ... 2100-12-31T12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:42:41Z
#     forcing:                        N/A
#     product:                        output
# MPI-ESM-LR
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34698)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2006-01-01T12:00:00 ... 2100-12-31T12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:40:54Z
#     forcing:                        N/A
#     product:                        output
# MIROC5
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34310)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2099-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:38:50Z
#     forcing:                        N/A
#     product:                        output
# MIROC-ESM
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34698)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2006-01-01T12:00:00 ... 2100-12-31T12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:37:04Z
#     forcing:                        N/A
#     product:                        output
# MIROC-ESM-CHEM
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34698)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2006-01-01T12:00:00 ... 2100-12-31T12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:35:18Z
#     forcing:                        N/A
#     product:                        output
# IPSL-CM5A-MR
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:33:29Z
#     forcing:                        N/A
#     product:                        output
# IPSL-CM5A-LR
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:31:25Z
#     forcing:                        N/A
#     product:                        output
# GFDL-ESM2M
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:27:53Z
#     forcing:                        N/A
#     product:                        output
# GFDL-ESM2G
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
#     tasmax   (time, lat, lon) float32 ...
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:26:06Z
#     forcing:                        N/A
#     product:                        output

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 20440)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 1950-01-01 12:00:00 ... 2005-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              pre-industrial control
#     parent_experiment_id:           piControl
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:28:53Z
#     forcing:                        N/A
#     product:                        output

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 20440)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 1950-01-01 12:00:00 ... 2005-12-31 12:00:00
# Data variables:
#     pr       (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              pre-industrial control
#     parent_experiment_id:           piControl
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T21:34:20Z
#     forcing:                        N/A
#     product:                        output

# %%
ds3
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 20440)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 1950-01-01 12:00:00 ... 2005-12-31 12:00:00
# Data variables:
#     tasmax   (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              pre-industrial control
#     parent_experiment_id:           piControl
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T20:32:17Z
#     forcing:                        N/A
#     product:                        output

# %%
import xarray as xr
ds = xr.open_dataset(opendap_url)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 34675)
# Coordinates:
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 2006-01-01 12:00:00 ... 2100-12-31 12:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
# Attributes: (12/34)
#     parent_experiment:              historical
#     parent_experiment_id:           historical
#     parent_experiment_rip:          r1i1p1
#     Conventions:                    CF-1.4
#     institution:                    NASA Earth Exchange, NASA Ames Research C...
#     institute_id:                   NASA-Ames
#     ...                             ...
#     project_id:                     NEXGDDP
#     table_id:                       Table day (12 November 2010)
#     source:                         BCSD 2014
#     creation_date:                  2015-01-07T19:30:19Z
#     forcing:                        N/A
#     product:                        output

# %%
nc
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format DAP2):
#     parent_experiment: historical
#     parent_experiment_id: historical
#     parent_experiment_rip: r1i1p1
#     Conventions: CF-1.4
#     institution: NASA Earth Exchange, NASA Ames Research Center, Moffett Field, CA 94035
#     institute_id: NASA-Ames
#     realm: atmos
#     modeling_realm: atmos
#     version: 1.0
#     downscalingModel: BCSD
#     experiment_id: rcp85
#     frequency: day
#     realization: 1
#     initialization_method: 1
#     physics_version: 1
#     tracking_id: b77e6a93-dd85-4665-910e-f1e3854dde71
#     driving_data_tracking_ids: N/A
#     driving_model_ensemble_member: r1i1p1
#     driving_experiment_name: historical
#     driving_experiment: historical
#     model_id: BCSD
#     references: BCSD method: Thrasher et al., 2012, Hydrol. Earth Syst. Sci.,16, 3309-3314.
# Ref period obs: latest version of the Princeton Global Meteorological Forcings (http://hydrology.princeton.edu/data.php),
# based on Sheffield et al., 2006, J. Climate, 19 (13), 3088-3111.
#     DOI: http://dx.doi.org/10.7292/W0MW2F2G
#     experiment: RCP8.5
#     title: INMCM4 global downscaled NEX CMIP5 Climate Projection, r1i1p1, RCP8.5
#     contact: Dr. Rama Nemani: rama.nemani@nasa.gov, Dr. Bridget Thrasher: bridget@climateanalyticsgroup.org
#     disclaimer: This data is considered provisional and subject to change. This data is provided as is without any warranty of any kind, either express or implied, arising by law or otherwise, including but not limited to warranties of completeness, non-infringement, accuracy, merchantability, or fitness for a particular purpose. The user assumes all risk associated with the use of, or inability to use, this data.
#     resolution_id: 0.25 degree
#     project_id: NEXGDDP
#     table_id: Table day (12 November 2010)
#     source: BCSD 2014
#     creation_date: 2015-01-07T19:30:19Z
#     forcing: N/A
#     product: output
#     dimensions(sizes): lat(720), lon(1440), time(34675)
#     variables(dimensions): float32 lat(lat), float32 lon(lon), float64 time(time), float32 tasmin(time, lat, lon)
#     groups:

# %%
# Adapted from: https://stackoverflow.com/a/37573701
def download(url, filename):
    print("Downloading ", filename)
    r = requests.get(url, stream=True)
    total_size, block_size = int(r.headers.get('content-length', 0)), 1024
    with open(filename, 'wb') as f:
        for data in tqdm(r.iter_content(block_size), total=total_size//block_size, unit='KiB', unit_scale=True):
            f.write(data)
            
    if total_size != 0 and os.path.getsize(filename) != total_size:
        print("Downloaded size does not match expected size!\n",
              "FYI, the status code was ", r.status_code)

# %%
download('https://ds.nccs.nasa.gov/thredds/catalog/bypass/NEX-GDDP/bcsd/rcp45/r1i1p1/tasmin/catalog.html?dataset=bypass/NEX-GDDP/bcsd/rcp45/r1i1p1/tasmin/bcc-csm1-1.ncml', "NC.nc")
# Out:
# Downloading  NC.nc
# 2.00KiB [00:00, 954KiB/s]

# %%
conn = SearchConnection('https://esgf-data.dkrz.de/esg-search', distrib=True)
query = conn.new_context(
    latest=True,
    project='CMIP5',
    model='HadCM3',
    experiment='rcp45',
    variable='pr,tasmax,tasmin',
    time_frequency="day",
    realm='atmos',
    ensemble='r1i1p1',
    data_node='esgf-data1.ceda.ac.uk')
results = query.search()

print('len(results)', len(results))
print('variables', results[0].json['variable'])
# Out:
# len(results) 1
# variables ['huss', 'pr', 'psl', 'sfcWind', 'ta', 'tas', 'tasmax', 'tasmin', 'ua', 'va', 'zg']

# %%
hit = results[0].file_context().search()
print('len(hit)', len(hit))

allfiles = map(lambda f : {'filename': f.filename, 'url': f.download_url}, hit)
allfiles = list(allfiles)
print('len(allfiles)', len(allfiles))
# Out:
# len(hit) 22
# len(allfiles) 22

# %%
files = []
for variable in ['tasmin', 'tasmax', 'pr']:
  result = list(filter(lambda x: variable in x['filename'], allfiles))
  files.extend(result)

files = pd.DataFrame.from_dict(files)
files
# Out:
#                                             filename                                                url
# 0  tasmin_day_HadCM3_rcp45_r1i1p1_20060101-203012...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 1  tasmin_day_HadCM3_rcp45_r1i1p1_20310101-203512...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 2  tasmax_day_HadCM3_rcp45_r1i1p1_20060101-203012...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 3  tasmax_day_HadCM3_rcp45_r1i1p1_20310101-203512...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 4    pr_day_HadCM3_rcp45_r1i1p1_20060101-20301230.nc  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 5    pr_day_HadCM3_rcp45_r1i1p1_20310101-20351230.nc  http://esgf-data1.ceda.ac.uk/thredds/fileServe...

# %%
 #drop the long-range (2101–2300) projections from our list of downloads
files = files[~files['filename'].str.contains("210101")]

#remove duplicate filenames
files = files.drop_duplicates(subset='filename', keep="first") 

files
# Out:
#                                             filename                                                url
# 0  tasmin_day_HadCM3_rcp45_r1i1p1_20060101-203012...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 1  tasmin_day_HadCM3_rcp45_r1i1p1_20310101-203512...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 2  tasmax_day_HadCM3_rcp45_r1i1p1_20060101-203012...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 3  tasmax_day_HadCM3_rcp45_r1i1p1_20310101-203512...  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 4    pr_day_HadCM3_rcp45_r1i1p1_20060101-20301230.nc  http://esgf-data1.ceda.ac.uk/thredds/fileServe...
# 5    pr_day_HadCM3_rcp45_r1i1p1_20310101-20351230.nc  http://esgf-data1.ceda.ac.uk/thredds/fileServe...

# %%
# Adapted from: https://stackoverflow.com/a/37573701
def download(url, filename):
    print("Downloading ", filename)
    r = requests.get(url, stream=True)
    total_size, block_size = int(r.headers.get('content-length', 0)), 1024
    with open(filename, 'wb') as f:
        for data in tqdm(r.iter_content(block_size), total=total_size//block_size, unit='KiB', unit_scale=True):
            f.write(data)
            
    if total_size != 0 and os.path.getsize(filename) != total_size:
        print("Downloaded size does not match expected size!\n",
              "FYI, the status code was ", r.status_code)

# %%
download(files.url[0], files.filename[0])
# Out:
# Downloading  tasmin_day_HadCM3_rcp45_r1i1p1_20060101-20301230.nc
# 247kKiB [00:24, 10.1kKiB/s]

# %%
nc_lat = nc.variables['lat'][:].data
nc_lon = nc.variables['lon'][:].data

# %%
nc = Dataset(files.filename[0])

time_start = date2index(dt.datetime(1981, 1, 1), nc_time, select="nearest")
time_end = date2index(dt.datetime(2100, 12, 31), nc_time, select="nearest")

num2date(nc_time[time_end], units=nc_time.units, calendar=nc_time.calendar)

nc_lat = nc.variables['lat'][:].data
nc_lon = nc.variables['lon'][:].data

bangui = pd.read_excel('Bangui_pts.xlsx', index_col=0, dtype={'id': int, 'lat': float, 'long': float})
banguiValues = []
for row in bangui.iterrows():
  banguiValues.append([row[1].long, row[1].lat])
  
polygonBangui = Polygon(banguiValues)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-218a2addd57e> in <module>()
# ----> 1 nc = Dataset(files.filename[0])
#       2
#       3 time_start = date2index(dt.datetime(1981, 1, 1), nc_time, select="nearest")
#       4 time_end = date2index(dt.datetime(2100, 12, 31), nc_time, select="nearest")
#       5
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'tasmin_day_HadCM3_rcp45_r1i1p1_20060101-20301230.nc'

# %%
import xarray as xr
ds = xr.open_dataset(files.url[0])
print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('http://esgf-data1.ceda.ac.uk/thredds/fileServer/esg_dataroot/cmip5/output1/MOHC/HadCM3/rcp45/day/atmos/day/r1i1p1/v20131125/tasmin/tasmin_day_HadCM3_rcp45_r1i1p1_20060101-20301230.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-dc8eb95545ae> in <module>()
#       1 import xarray as xr
# ----> 2 ds = xr.open_dataset(files.url[0])
#       3 print(ds)
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     498         drop_variables=drop_variables,
#     499         **decoders,
# --> 500         **kwargs,
#     501     )
#     502     ds = _dataset_from_backend_dataset(
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/netCDF4_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     556             persist=persist,
#     557             lock=lock,
# --> 558             autoclose=autoclose,
#     559         )
#     560
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     378             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     379         )
# --> 380         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     381
#     382     def _acquire(self, needs_lock=True):
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     326         self._group = group
#     327         self._mode = mode
# --> 328         self.format = self.ds.data_model
#     329         self._filename = self.ds.filepath()
#     330         self.is_remote = is_remote_uri(self._filename)
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/netCDF4_.py in ds(self)
#     387     @property
#     388     def ds(self):
# --> 389         return self._acquire()
#     390
#     391     def open_store_variable(self, name, var):
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     381
#     382     def _acquire(self, needs_lock=True):
# --> 383         with self._manager.acquire_context(needs_lock) as root:
#     384             ds = _nc4_require_group(root, self._group, self._mode)
#     385         return ds
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# /usr/local/lib/python3.7/dist-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -90] NetCDF: file not found: b'http://esgf-data1.ceda.ac.uk/thredds/fileServer/esg_dataroot/cmip5/output1/MOHC/HadCM3/rcp45/day/atmos/day/r1i1p1/v20131125/tasmin/tasmin_day_HadCM3_rcp45_r1i1p1_20060101-20301230.nc'

# %%
nc = Dataset(files.filename[0])
nc.dimensions
# Out:
# {'bnds': <class 'netCDF4._netCDF4.Dimension'>: name = 'bnds', size = 2,
#  'lat': <class 'netCDF4._netCDF4.Dimension'>: name = 'lat', size = 73,
#  'lon': <class 'netCDF4._netCDF4.Dimension'>: name = 'lon', size = 96,
#  'time': <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 9000}

# %%
nc_lat = nc.variables['lat'][:].data
len(nc_lat)
# Out:
# 73

# %%
nc_lon = nc.variables['lon'][:].data
len(nc_lon)
# Out:
# 96

# %%
nc_lat = nc.variables['lat'][:].data
lat_cell = np.where((nc_lat[:,0] < row[1].lat) & (nc_lat[:,1] > row[1].lat))[0][0]

nc_lon = nc.variables['lon'][:].data
lon_cell = np.where(polygonBangui.contains(Point(row[1].long, row[1].long)) (nc_lon[:,0] < row[1].long) & (nc_lon[:,1] > row[1].long))[0][0]

dat = nc.variables['tasmin'][time_start:(time_end + 1), lat_cell, lon_cell]
dat = np.subtract(dat.data, 273.15)
dates = num2date(nc_time[time_start:time_end + 1], units=nc_time.units, calendar=nc_time.calendar)
df = pd.DataFrame({'Date': dates, 'Tmin': dat})
df.head()

# %%
nc_lat_bnds = nc.variables["lat_bnds"][:].data
lat_cell = np.where((nc_lat_bnds[:,0] < row[1].lat) & (nc_lat_bnds[:,1] > row[1].lat))[0][0]

nc_lon_bnds = nc.variables["lon_bnds"][:].data
lon_cell = np.where((nc_lon_bnds[:,0] < row[1].long) & (nc_lon_bnds[:,1] > row[1].long))[0][0]

dat = nc.variables['tasmin'][time_start:(time_end + 1), lat_cell, lon_cell]
dat = np.subtract(dat.data, 273.15)
dates = num2date(nc_time[time_start:time_end + 1], units=nc_time.units, calendar=nc_time.calendar)
df = pd.DataFrame({'Date': dates, 'Tmin': dat})
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-361-9029972d320e> in <module>()
#       5 lon_cell = np.where((nc_lon_bnds[:,0] < row[1].long) & (nc_lon_bnds[:,1] > row[1].long))[0][0]
#       6
# ----> 7 dat = nc.variables['tasmax'][time_start:(time_end + 1), lat_cell, lon_cell]
#       8 dat = np.subtract(dat.data, 273.15)
#       9 dates = num2date(nc_time[time_start:time_end + 1], units=nc_time.units, calendar=nc_time.calendar)
#
# KeyError: 'tasmax'

# %%
df.head()
# Out:
#                   Date   MeanTemp
# 0  2006-01-01 12:00:00  17.978607
# 1  2006-01-02 12:00:00  17.908112
# 2  2006-01-03 12:00:00  17.334320
# 3  2006-01-04 12:00:00  18.653046
# 4  2006-01-05 12:00:00  17.960724
